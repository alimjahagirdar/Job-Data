# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("H:\isa\Car_sales.csv")
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#meta data about dataset
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
# dropping rows that has Nan data
df1 = df.dropna().reset_index().drop(["index"],axis=1)
df1
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       RL               8.588               29.725
# 3           Audi       A4              20.397               22.255
# 4           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 112   Volkswagen     Golf               9.761               11.425
# 113   Volkswagen    Jetta              83.721               13.240
# 114   Volkswagen   Passat              51.102               16.725
# 115   Volkswagen   Cabrio               9.569               16.575
# 116   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#checking for duplicated entries
df.duplicated().sum()
# Out:
# 0

# %%
#transpose gives a better view of dataset when rows are many
df.T
# Out:
#                            0          1          2          3          4    \
# Manufacturer             Acura      Acura      Acura      Acura       Audi
# Model                  Integra         TL         CL         RL         A4
# Sales_in_thousands      16.919     39.384     14.114      8.588     20.397
# __year_resale_value      16.36     19.875     18.225     29.725     22.255
# Vehicle_type         Passenger  Passenger  Passenger  Passenger  Passenger
# Price_in_thousands        21.5       28.4        NaN       42.0      23.99
# Engine_size                1.8        3.2        3.2        3.5        1.8
# Horsepower               140.0      225.0      225.0      210.0      150.0
# Wheelbase                101.2      108.1      106.9      114.6      102.6
# Width                     67.3       70.3       70.6       71.4       68.2
# Length                   172.4      192.9      192.0      196.6      178.0
# ...

# %%
#grouping the car models according to the macfacturer 
dfgroup =df.groupby(['Manufacturer'])['Model'].count()
dfgroup
# Out:
# Manufacturer
# Acura          4
# Audi           3
# BMW            3
# Buick          4
# Cadillac       5
# Chevrolet      9
# Chrysler       7
# Dodge         11
# Ford          11
# Honda          5
# Hyundai        3
# Infiniti       1
# Jaguar         1
# Jeep           3
# Lexus          6
# Lincoln        3
# Mercedes-B     9
# Mercury        6
# Mitsubishi     7
# Nissan         7
# Oldsmobile     6
# Plymouth       4
# Pontiac        6
# Porsche        3
# Saab           2
# Saturn         5
# Subaru         2
# Toyota         9
# Volkswagen     6
# Volvo          6
# Name: Model, dtype: int64

# %%
# finding number of manufacturer in the dataset
df["Manufacturer"].unique().size
# Out:
# 30

# %%
#finding manufacturer in the datasets
unique = df["Manufacturer"].unique()
unique = sorted(unique)
unique
# Out:
# ['Acura',
#  'Audi',
#  'BMW',
#  'Buick',
#  'Cadillac',
#  'Chevrolet',
#  'Chrysler',
#  'Dodge',
#  'Ford',
#  'Honda',
#  'Hyundai',
#  'Infiniti',
#  'Jaguar',
#  'Jeep',
#  'Lexus',
#  'Lincoln',
#  'Mercedes-B',
#  'Mercury',
#  'Mitsubishi',
#  'Nissan',
#  'Oldsmobile',
#  'Plymouth',
#  'Pontiac',
#  'Porsche',
#  'Saab',
#  'Saturn',
#  'Subaru',
#  'Toyota',
#  'Volkswagen',
#  'Volvo']

# %%
# finding type of vehicle in the datasets
vehicle_type = df['Vehicle_type'].value_counts()
vehicle_type
# Out:
# Passenger    116
# Car           41
# Name: Vehicle_type, dtype: int64

# %%
# finding count type of vehicle in the datasets
type = df["Vehicle_type"].unique()
type
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %%
#vehicle types in data sets
plt.pie(vehicle_type,labels=type,autopct=lambda p:f' {p*sum(vehicle_type)/100 :.0f}')
plt.title("count of vehicle type")
plt.show()

# %%
#number of models produced by Manufacturer 

fig,ax = plt.subplots(figsize =(10, 9))
plt.barh(unique,dfgroup)

for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='black')

plt.title('models produced by manufacturer')

plt.show()

# %%
#finding sales of manufacturer
sale = df.groupby(["Manufacturer"])["Sales_in_thousands"].sum().to_frame()
sale
# Out:
#               Sales_in_thousands
# Manufacturer
# Acura                     79.005
# Audi                      40.557
# BMW                       46.505
# Buick                    242.019
# Cadillac                 112.178
# Chevrolet                554.365
# Chrysler                 201.721
# Dodge                    910.149
# Ford                    2022.635
# Honda                    592.674
# Hyundai                  137.326
# Infiniti                  23.713
# Jaguar                    15.467
# Jeep                     293.153
# Lexus                    106.843
# Lincoln                   85.634
# Mercedes-B               117.125
# Mercury                  237.999
# Mitsubishi               180.895
# Nissan                   399.635
# Oldsmobile               178.989
# Plymouth                  64.001
# Pontiac                  370.534
# Porsche                   12.128
# Saab                      21.306
# Saturn                   168.850
# Subaru                    80.135
# ...

# %%
sale.plot.bar(title="sales of models by manufacturer ")
plt.show()

# %%
#Total price of models by manufacturer
price = df.groupby(["Manufacturer"])["Price_in_thousands"].sum().to_frame()
price
# Out:
#               Price_in_thousands
# Manufacturer
# Acura                     91.900
# Audi                     119.940
# BMW                       99.290
# Buick                    107.125
# Cadillac                 201.270
# Chevrolet                180.205
# Chrysler                 140.585
# Dodge                    266.350
# Ford                     231.520
# Honda                    101.385
# Hyundai                   36.497
# Infiniti                  29.465
# Jaguar                    42.800
# Jeep                      62.975
# Lexus                    264.330
# Lincoln                  125.070
# Mercedes-B               476.250
# Mercury                  124.490
# Mitsubishi               155.172
# Nissan                   156.525
# Oldsmobile               153.737
# Plymouth                  90.570
# Pontiac                  137.695
# Porsche                  187.420
# Saab                      59.220
# Saturn                    71.355
# Subaru                    42.790
# ...

# %%
price1.plot.bar(title="Total price of models by manufacturer ")
plt.show()

# %%
brand=df.loc[(df.Manufacturer == 'Mercedes-B')]
mercedes=brand[["Manufacturer","Model","Price_in_thousands"]]
mercedes
# Out:
#     Manufacturer      Model  Price_in_thousands
# 92    Mercedes-B    C-Class               31.75
# 93    Mercedes-B    E-Class               49.90
# 94    Mercedes-B    S-Class               69.70
# 95    Mercedes-B   SL-Class               82.60
# 96    Mercedes-B        SLK               38.90
# 97    Mercedes-B     SLK230               41.00
# 98    Mercedes-B  CLK Coupe               41.60
# 99    Mercedes-B      CL500               85.50
# 100   Mercedes-B    M-Class               35.30

# %%
brand1=df.loc[(df.Manufacturer == 'Ford')]
ford=brand1[["Manufacturer","Model","Price_in_thousands"]]
ford
# Out:
#    Manufacturer           Model  Price_in_thousands
# 46         Ford          Escort              12.070
# 47         Ford         Mustang              21.560
# 48         Ford         Contour              17.035
# 49         Ford          Taurus              17.885
# 50         Ford           Focus              12.315
# 51         Ford  Crown Victoria              22.195
# 52         Ford        Explorer              31.930
# 53         Ford        Windstar              21.410
# 54         Ford      Expedition              36.135
# 55         Ford          Ranger              12.050
# 56         Ford        F-Series              26.935

# %%
plt.barh(brand["Model"],brand["Price_in_thousands"], label='Mercedes')
plt.barh(brand1["Model"],brand1["Price_in_thousands"], label='ford')
plt.title("mercedes-B v/s ford model prices")
plt.legend()
plt.show()

# %%
df.corr()
# Out:
# C:\Users\alimj\AppData\Local\Temp\ipykernel_10124\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Sales_in_thousands  __year_resale_value  \
# Sales_in_thousands             1.000000            -0.279034
# __year_resale_value           -0.279034             1.000000
# Price_in_thousands            -0.304734             0.953840
# Engine_size                    0.019983             0.531330
# Horsepower                    -0.197756             0.769081
# Wheelbase                      0.358179            -0.052270
# Width                          0.140918             0.178767
# Length                         0.254980             0.026548
# Curb_weight                    0.008628             0.361557
# Fuel_capacity                  0.086540             0.325567
# ...

# %%
#whats makes vehicle expensive
plt.scatter(df["Engine_size"],df["Price_in_thousands"])
plt.title("engine size v/s price in thousand")
plt.show()
